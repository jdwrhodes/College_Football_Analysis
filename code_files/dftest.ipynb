# %%
# Dependencies and setup
import pandas as pd
import os
import glob

# %%
#Files to load
college_football_data = '../source_data/cfb*.csv'

# %%
all_files = glob.glob(college_football_data)

# %%
df = (pd.read_csv(f) for f in all_files)

# %%
dataframes_list = []

# %%
for x in all_files:
    temp_df = pd.read_csv(x)
    dataframes_list.append(temp_df)

# %%
#for dataset in dataframes_list:
    #display(dataset)

# %%
#Show Just 1 Dataset from the DataFrame
display(dataframes_list[1])
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0                Akron (MAC)     12    5     7        88        891
# 1              Alabama (SEC)     14   12     2        17       1018
# 2           Arizona (Pac-12)     14   10     4        25       1139
# 3       Arizona St. (Pac-12)     13   10     3        34        975
# 4             Arkansas (SEC)     13    7     6        60        916
# ..                       ...    ...  ...   ...       ...        ...
# 108  Washington St. (Pac-12)     12    3     9         7       1014
# 109   West Virginia (Big 12)     13    7     6        12       1097
# 110      Western Ky. (C-USA)     13    8     5         4        986
# 111      Western Mich. (MAC)     13    8     5        39        875
# 112      Wisconsin (Big Ten)     14   11     3        21        970
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Total.TDs  ...  \
# 0         4479            5.03       32         33  ...
# ...

# %%
#Convert one of the Lists into a Dataframe
df_2013=pd.DataFrame(dataframes_list[1])

# %%
#Print the Dataframe
df_2013.head(100)
# Out:
#                     Team  Games  Win  Loss  Off.Rank  Off.Plays  Off.Yards  \
# 0            Akron (MAC)     12    5     7        88        891       4479
# 1          Alabama (SEC)     14   12     2        17       1018       6783
# 2       Arizona (Pac-12)     14   10     4        25       1139       6491
# 3   Arizona St. (Pac-12)     13   10     3        34        975       5750
# 4         Arkansas (SEC)     13    7     6        60        916       5278
# ..                   ...    ...  ...   ...       ...        ...        ...
# 95           Tulsa (AAC)     12    2    10        56        958       4950
# 96           UAB (C-USA)     12    6     6        42        941       5182
# 97             UCF (AAC)     13    9     4        99        942       4727
# 98         UCLA (Pac-12)     13   10     3        22        992       6082
# 99           UConn (AAC)     12    2    10       123        736       3315
#
#     Off.Yards.Play  Off.TDs  Total.TDs  ...  \
# ...

# %%
#Get a list of the Column Names
df_2013_col_names = list(df_2013.columns)

# %%
#Column Datatypes?
df_2013.dtypes
# Out:
# Team                             object
# Games                             int64
# Win                               int64
# Loss                              int64
# Off.Rank                          int64
#                                  ...
# Fumbles.Lost                      int64
# Interceptions.Thrown.y            int64
# Turnovers.Lost                    int64
# Turnover.Margin                   int64
# Avg.Turnover.Margin.per.Game    float64
# Length: 146, dtype: object

# %%
df_2013.isnull().sum()
# Out:
# Team                            0
# Games                           0
# Win                             0
# Loss                            0
# Off.Rank                        0
#                                ..
# Fumbles.Lost                    0
# Interceptions.Thrown.y          0
# Turnovers.Lost                  0
# Turnover.Margin                 0
# Avg.Turnover.Margin.per.Game    0
# Length: 146, dtype: int64

# %%
#Try to determine which Stat/column has the most and least impact on Wins.

# %%
#Print only SEC Teams to the console
df_2013[df_2013['Team'].str.contains("")]
# Out:
# C:\Users\josrh\AppData\Local\Temp\ipykernel_16976\3636723126.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_2013[df_2013['Team'].str.contains("'()'")]
# Empty DataFrame
# ...

# %%
#After finding that Ole Miss was missing, I wanted to figure out what other rows were missing the conference.
df_2013[df_2013['Team'].str.endswith("()")]
# Out:
#              Team  Games  Win  Loss  Off.Rank  Off.Plays  Off.Yards  \
# 69    Ole Miss ()     13    9     4        51        904       5448
# 73  Pittsburgh ()     13    6     7        40        918       5660
#
#     Off.Yards.Play  Off.TDs  Total.TDs  ...  \
# 69            6.03       45         49  ...
# 73            6.17       52         52  ...
#
#     Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 69                                28:14             27                 10
# 73                                33:49             95                  4
#
#     Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 69                     22              32            10
# 73                     10              14            12
#
#     Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 69                      15              25                7
# 73                       7              19               -5
#
#     Avg.Turnover.Margin.per.Game
# ...

# %%
#Now I want to edit those cells and add the correct coference
df_2013.iat[69,0] = 'Ole Miss (SEC)'

# %%
#I'll do the same to Pitt now
df_2013.iat[73,0] = 'Pittsburgh (ACC)'

# %%
#Now I'll get the SEC teams again
df_2013[df_2013['Team'].str.contains('SEC')]
# Out:
#                       Team  Games  Win  Loss  Off.Rank  Off.Plays  Off.Yards  \
# 1            Alabama (SEC)     14   12     2        17       1018       6783
# 4           Arkansas (SEC)     13    7     6        60        916       5278
# 7             Auburn (SEC)     13    8     5        16        939       6305
# 24           Florida (SEC)     12    7     5        93        841       4411
# 26           Georgia (SEC)     13   10     3        28        877       5951
# 38          Kentucky (SEC)     12    5     7        79        849       4612
# 43               LSU (SEC)     13    8     5        77        897       5037
# 54   Mississippi St. (SEC)     13   10     3         8       1001       6679
# 55          Missouri (SEC)     14   11     3        95        954       5138
# 69          Ole Miss (SEC)     13    9     4        51        904       5448
# 79    South Carolina (SEC)     13    7     6        33        947       5764
# ...

# %% [markdown]
# <h1>Success!</h1>

# %%
#Next let's try to list the teams by conference
